# %% [markdown]
# <a href="https://colab.research.google.com/github/TrungDuc2803/yolov5/blob/main/Train_model_Yolov5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16656, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 16656 (delta 1), reused 0 (delta 0), pack-reused 16649
# Receiving objects: 100% (16656/16656), 15.12 MiB | 16.28 MiB/s, done.
# Resolving deltas: 100% (11438/11438), done.

# %%
# !pip install -r /content/yolov5/requirements.txt

# %%
# !unrar x /content/coco128.rar

# %%
# !python /content/yolov5/train.py --img 640 --batch 24 --epochs 150 --data coco128.yaml --weights yolov5s.pt
# Out:
# 2024-05-30 14:35:26.619510: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-30 14:35:26.619575: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-30 14:35:26.621541: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python /content/yolov5/detect.py --source /content/coco128/images/train2017/
# Out:
# detect: weights=/content/yolov5/runs/train/exp2/weights/best.pt, source=/content/coco128/images/train2017/, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-318-gc0380fd8 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/23 /content/coco128/images/train2017/05545660-capture_50.jpg: 480x640 1 cafe, 1 xanh, 51.1ms
# image 2/23 /content/coco128/images/train2017/0bbc33bb-capture_48.jpg: 480x640 1 cafe, 1 xanh, 8.9ms
# ...

# %%
# !python /content/yolov5/detect.py --source /content/drive.mp4
# Out:
# detect: weights=/content/yolov5/runs/train/exp/weights/best.pt, source=/content/coco128/images/train2017/3aea10ec-capture_45.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-318-gc0380fd8 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/coco128/images/train2017/3aea10ec-capture_45.jpg: 480x640 (no detections), 49.9ms
# Speed: 0.5ms pre-process, 49.9ms inference, 19.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/exp2

# %%
# !python /content/yolov5/train.py --img 640 --batch 16 --epochs 50 --data /content/yolov5/data/coco128.yaml --bbox_interval 1 --weights yolov5s.pt
